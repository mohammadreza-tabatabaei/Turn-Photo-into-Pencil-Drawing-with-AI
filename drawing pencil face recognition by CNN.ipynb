# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import cv2
import numpy as np
import glob
import matplotlib.pyplot as plt

width=200
height=200

Data=[]
for i in range(1,101):
  img = '/content/drive/My Drive/DataSet/Face/' + str(i) + '.jpg'
  im=cv2.imread(img)
  im=cv2.resize(im,(width,height))
  Data.append(im)

# %%
def Sketch_Convertor(image):
  grey_Filter=cv2.cvtColor(image,cv2.COLOR_RGB2GRAY)
  invert=cv2.bitwise_not(grey_Filter)
  blur=cv2.GaussianBlur(invert,(21,21),0)
  Invertedblur=cv2.bitwise_not(blur)
  Sketch_Filter=cv2.divide(grey_Filter,Invertedblur,scale=256)
  return Sketch_Filter

# %%
Sketch_Filter=Sketch_Convertor(im)

# %%
Sketch_Filter=Sketch_Convertor(im)
imgplot = plt.imshow(im)
plt.gray()
plt.show()
print('Pencil Drawing')
imgplot = plt.imshow(Sketch_Filter)
plt.gray()
plt.show()
# Out:
# Pencil Drawing

# %%
Target=[]
counter=1
idx_Class=0
for i in range(1,101):
  if(counter==21):
    counter=1
    idx_Class=idx_Class+1
  Target.append(idx_Class)
  counter=counter+1

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(Data, Target, test_size=0.3, random_state=42)

# %%
import numpy as np

# %%
X_train=np.array(X_train)
X_test=np.array(X_test)

# %%
X_train = X_train.reshape(len(X_train), width,height,3)
X_test = X_test.reshape(len(X_test), width,height,3)

# %%
from keras.utils import np_utils
Y_train = np_utils.to_categorical(y_train)
Y_test = np_utils.to_categorical(y_test)

# %%
def plot_history(net_history):
    history = net_history.history
    import matplotlib.pyplot as plt
    losses = history['loss']
    val_losses = history['val_loss']
    accuracies = history['accuracy']
    val_accuracies = history['val_accuracy']
    
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.plot(losses)
    plt.plot(val_losses)
    plt.legend(['loss', 'val_loss'])
    
    plt.figure()
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.plot(accuracies)
    plt.plot(val_accuracies)
    plt.legend(['acc', 'val_acc'])

# %%
'''
How can I fight overfitting?
1- Get more data (or data augmentation)
2- Dropout (see paper, explanation, dropout for cnns)
3- DropConnect.
4- Regularization (see my masters thesis, page 85 for examples)
5- Feature scale clipping.
6- Global average pooling.
7- Make network smaller.
8- Early stopping.

'''


# How can I fight overfitting?
# 1- Get more data (or data augmentation)
# 2- Dropout (see paper, explanation, dropout for cnns)
# 3- DropConnect.
# 4- Regularization (see my masters thesis, page 85 for examples)
# 5- Feature scale clipping.
# 6- Global average pooling.
# 7- Make network smaller.
# 8- Early stopping.

# %%
#==================================================
# Creating our model
from keras.models import Model
from keras import layers
import keras

myInput = layers.Input(shape=(width,height,3))
conv1 = layers.Conv2D(16, 3, activation='relu', padding='same')(myInput)
maxpool1=layers.MaxPooling2D(2)(conv1)
drop1=layers.Dropout(0.2)(maxpool1)
conv2 = layers.Conv2D(32, 3, activation='relu', padding='same', strides=2)(drop1)
drop2=layers.Dropout(0.2)(conv2)
conv3 = layers.Conv2D(64, 3, activation='relu', padding='same')(drop2)
maxpool2=layers.MaxPooling2D(2)(conv3)
drop3=layers.Dropout(0.2)(maxpool2)

flat = layers.Flatten()(drop3)
dns1=layers.Dense(100, activation='relu')(flat)
out_layer = layers.Dense(5, activation='softmax')(dns1)

myModel = Model(myInput, out_layer)

myModel.summary()
myModel.compile(optimizer=keras.optimizers.Adam(), loss=keras.losses.categorical_crossentropy, metrics=['accuracy'])

#==================================================
# Train our model
network_history = myModel.fit(X_train, Y_train, batch_size=2, epochs=20, validation_split=0.2)
plot_history(network_history)
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 200, 200, 3)]     0
#
#  conv2d_3 (Conv2D)           (None, 200, 200, 16)      448
#
#  max_pooling2d_2 (MaxPooling  (None, 100, 100, 16)     0
#  2D)
#
#  dropout_3 (Dropout)         (None, 100, 100, 16)      0
#
#  conv2d_4 (Conv2D)           (None, 50, 50, 32)        4640
#
#  dropout_4 (Dropout)         (None, 50, 50, 32)        0
#
#  conv2d_5 (Conv2D)           (None, 50, 50, 64)        18496
#
#  max_pooling2d_3 (MaxPooling  (None, 25, 25, 64)       0
#  2D)
#
#  dropout_5 (Dropout)         (None, 25, 25, 64)        0
#
#  flatten_1 (Flatten)         (None, 40000)             0
#
#  dense_2 (Dense)             (None, 100)               4000100
#
#  dense_3 (Dense)             (None, 5)                 505
#
# =================================================================
# Total params: 4,024,189
# Trainable params: 4,024,189
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 28/28 [==============================] - 3s 89ms/step - loss: 248.3718 - accuracy: 0.2857 - val_loss: 1.5696 - val_accuracy: 0.1429
# Epoch 2/20
# 28/28 [==============================] - 3s 103ms/step - loss: 1.5642 - accuracy: 0.3750 - val_loss: 1.6039 - val_accuracy: 0.2143
# Epoch 3/20
# 28/28 [==============================] - 3s 95ms/step - loss: 1.2426 - accuracy: 0.5357 - val_loss: 1.5883 - val_accuracy: 0.1429
# Epoch 4/20
# 28/28 [==============================] - 2s 78ms/step - loss: 1.0538 - accuracy: 0.5536 - val_loss: 1.5598 - val_accuracy: 0.2143
# Epoch 5/20
# 28/28 [==============================] - 2s 76ms/step - loss: 0.7391 - accuracy: 0.7143 - val_loss: 1.5589 - val_accuracy: 0.2143
# Epoch 6/20
# 28/28 [==============================] - 2s 77ms/step - loss: 0.5786 - accuracy: 0.7679 - val_loss: 1.8603 - val_accuracy: 0.2857
# Epoch 7/20
# 28/28 [==============================] - 2s 85ms/step - loss: 0.4372 - accuracy: 0.8750 - val_loss: 1.7407 - val_accuracy: 0.2143
# Epoch 8/20
# 28/28 [==============================] - 4s 127ms/step - loss: 0.2300 - accuracy: 0.9286 - val_loss: 1.7321 - val_accuracy: 0.2143
# Epoch 9/20
# 28/28 [==============================] - 2s 79ms/step - loss: 0.1830 - accuracy: 0.9286 - val_loss: 1.6041 - val_accuracy: 0.2857
# Epoch 10/20
# 28/28 [==============================] - 2s 78ms/step - loss: 0.1456 - accuracy: 0.9286 - val_loss: 1.5505 - val_accuracy: 0.3571
# Epoch 11/20
# 28/28 [==============================] - 2s 78ms/step - loss: 0.0291 - accuracy: 1.0000 - val_loss: 1.5163 - val_accuracy: 0.2143
# Epoch 12/20
# 28/28 [==============================] - 2s 77ms/step - loss: 0.1384 - accuracy: 0.9643 - val_loss: 1.6671 - val_accuracy: 0.3571
# Epoch 13/20
# 28/28 [==============================] - 3s 121ms/step - loss: 0.0386 - accuracy: 0.9821 - val_loss: 1.7227 - val_accuracy: 0.5000
# Epoch 14/20
# 28/28 [==============================] - 2s 79ms/step - loss: 0.0508 - accuracy: 0.9643 - val_loss: 1.7007 - val_accuracy: 0.5000
# Epoch 15/20
# 28/28 [==============================] - 2s 77ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 2.6459 - val_accuracy: 0.3571
# Epoch 16/20
# 28/28 [==============================] - 2s 77ms/step - loss: 0.3240 - accuracy: 0.9107 - val_loss: 1.4071 - val_accuracy: 0.2857
# Epoch 17/20
# 28/28 [==============================] - 2s 77ms/step - loss: 0.0781 - accuracy: 0.9643 - val_loss: 1.5496 - val_accuracy: 0.2857
# Epoch 18/20
# 28/28 [==============================] - 3s 105ms/step - loss: 0.0340 - accuracy: 1.0000 - val_loss: 1.5826 - val_accuracy: 0.3571
# Epoch 19/20
# 28/28 [==============================] - 3s 92ms/step - loss: 0.2309 - accuracy: 0.9286 - val_loss: 1.9957 - val_accuracy: 0.3571
# Epoch 20/20
# 28/28 [==============================] - 2s 78ms/step - loss: 0.3788 - accuracy: 0.9107 - val_loss: 2.1671 - val_accuracy: 0.5000

# %%
test_labels_p = myModel.predict(X_test)
import numpy as np
Out_CONV = np.argmax(test_labels_p, axis=1)
# Out:
# 1/1 [==============================] - 1s 559ms/step

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay
print(confusion_matrix(y_test,Out_CONV))
print(' ')
cm_display=ConfusionMatrixDisplay(confusion_matrix(y_test,Out_CONV))
cm_display.plot()
plt.show()
# Out:
# [[1 1 0 2 3]
#  [0 0 1 2 3]
#  [0 1 3 1 1]
#  [0 1 0 4 1]
#  [0 0 1 2 2]]

# %%
from sklearn.metrics import classification_report, accuracy_score
print('Accuracy= ' + str(round(accuracy_score(y_test, Out_CONV)*100)))
# Out:
# Accuracy= 33

# %%
print(classification_report(y_test,Out_CONV))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.14      0.25         7
#            1       0.00      0.00      0.00         6
#            2       0.60      0.50      0.55         6
#            3       0.36      0.67      0.47         6
#            4       0.20      0.40      0.27         5
#
#     accuracy                           0.33        30
#    macro avg       0.43      0.34      0.31        30
# weighted avg       0.46      0.33      0.31        30
